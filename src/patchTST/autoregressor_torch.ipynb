# %%
from utils.DataPreprocessing import dataloader
from loguru import logger
import os

lag = 20 # number of previous time steps to consider
n_features = 15 # number of features
n_steps_out = 1 # number of output steps (how many future steps are we going to predict?)

n_epochs = 60 # 1000 epochs
learning_rate = 0.01 # 0.001 lr

hidden_size = 100 # number of features in hidden state
num_layers = 1 # number of stacked lstm layers

path = os.path.dirname(os.path.dirname(os.getcwd()))
print(path)
data = dataloader(path=path, lag=lag)
# Out:
# 2024-04-13 20:40:31.104 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_103, 3)
# ┌───────────┬─────────────┬────────────┐
# │ AVG_TEMP  ┆ AVG_TEMP_DC ┆ date       │
# │ ---       ┆ ---         ┆ ---        │
# │ f32       ┆ str         ┆ date       │
# ╞═══════════╪═════════════╪════════════╡
# │ 29.299999 ┆ C           ┆ 1992-07-01 │
# │ 29.200001 ┆ C           ┆ 1992-07-02 │
# │ 29.6      ┆ C           ┆ 1992-07-03 │
# │ 29.299999 ┆ C           ┆ 1992-07-04 │
# │ 29.299999 ┆ C           ┆ 1992-07-05 │
# │ …         ┆ …           ┆ …          │
# │ 22.200001 ┆ C           ┆ 2022-11-26 │
# │ 22.4      ┆ C           ┆ 2022-11-27 │
# │ 25.4      ┆ C           ┆ 2022-11-28 │
# │ 25.1      ┆ C           ┆ 2022-11-29 │
# │ 22.1      ┆ C           ┆ 2022-11-30 │
# └───────────┴─────────────┴────────────┘
# 2024-04-13 20:40:31.105 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌──────────┬─────────────┬──────┐
# │ AVG_TEMP ┆ AVG_TEMP_DC ┆ date │
# │ ---      ┆ ---         ┆ ---  │
# │ u32      ┆ u32         ┆ u32  │
# ╞══════════╪═════════════╪══════╡
# │ 0        ┆ 0           ┆ 0    │
# └──────────┴─────────────┴──────┘
# 2024-04-13 20:40:31.112 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_110, 3)
# ┌───────────┬────────┬────────────┐
# │ GSR       ┆ GSR_DC ┆ date       │
# │ ---       ┆ ---    ┆ ---        │
# │ f32       ┆ str    ┆ date       │
# ╞═══════════╪════════╪════════════╡
# │ 20.1      ┆ C      ┆ 1992-07-01 │
# │ 17.76     ┆ C      ┆ 1992-07-02 │
# │ 19.799999 ┆ C      ┆ 1992-07-03 │
# │ 9.19      ┆ C      ┆ 1992-07-04 │
# │ 14.14     ┆ C      ┆ 1992-07-05 │
# │ …         ┆ …      ┆ …          │
# │ 4.27      ┆ C      ┆ 2022-11-26 │
# │ 3.66      ┆ C      ┆ 2022-11-27 │
# │ 11.34     ┆ C      ┆ 2022-11-28 │
# │ 17.049999 ┆ C      ┆ 2022-11-29 │
# │ 7.06      ┆ C      ┆ 2022-11-30 │
# └───────────┴────────┴────────────┘
# 2024-04-13 20:40:31.114 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬────────┬──────┐
# │ GSR ┆ GSR_DC ┆ date │
# │ --- ┆ ---    ┆ ---  │
# │ u32 ┆ u32    ┆ u32  │
# ╞═════╪════════╪══════╡
# │ 0   ┆ 0      ┆ 0    │
# └─────┴────────┴──────┘
# 2024-04-13 20:40:31.122 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_101, 3)
# ┌──────┬───────┬────────────┐
# │ RH   ┆ RH_DC ┆ date       │
# │ ---  ┆ ---   ┆ ---        │
# │ f32  ┆ str   ┆ date       │
# ╞══════╪═══════╪════════════╡
# │ 80.0 ┆ C     ┆ 1992-07-01 │
# │ 81.0 ┆ C     ┆ 1992-07-02 │
# │ 79.0 ┆ C     ┆ 1992-07-03 │
# │ 82.0 ┆ C     ┆ 1992-07-04 │
# │ 81.0 ┆ C     ┆ 1992-07-05 │
# │ …    ┆ …     ┆ …          │
# │ 89.0 ┆ C     ┆ 2022-11-26 │
# │ 92.0 ┆ C     ┆ 2022-11-27 │
# │ 88.0 ┆ C     ┆ 2022-11-28 │
# │ 86.0 ┆ C     ┆ 2022-11-29 │
# │ 83.0 ┆ C     ┆ 2022-11-30 │
# └──────┴───────┴────────────┘
# 2024-04-13 20:40:31.124 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬───────┬──────┐
# │ RH  ┆ RH_DC ┆ date │
# │ --- ┆ ---   ┆ ---  │
# │ u32 ┆ u32   ┆ u32  │
# ╞═════╪═══════╪══════╡
# │ 0   ┆ 0     ┆ 0    │
# └─────┴───────┴──────┘
# 2024-04-13 20:40:31.131 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_110, 3)
# ┌──────┬────────┬────────────┐
# │ SUN  ┆ SUN_DC ┆ date       │
# │ ---  ┆ ---    ┆ ---        │
# │ f32  ┆ str    ┆ date       │
# ╞══════╪════════╪════════════╡
# │ 10.7 ┆ C      ┆ 1992-07-01 │
# │ 8.4  ┆ C      ┆ 1992-07-02 │
# │ 8.6  ┆ C      ┆ 1992-07-03 │
# │ 1.4  ┆ C      ┆ 1992-07-04 │
# │ 1.5  ┆ C      ┆ 1992-07-05 │
# │ …    ┆ …      ┆ …          │
# │ 0.2  ┆ C      ┆ 2022-11-26 │
# │ 0.0  ┆ C      ┆ 2022-11-27 │
# │ 4.2  ┆ C      ┆ 2022-11-28 │
# │ 8.9  ┆ C      ┆ 2022-11-29 │
# │ 2.6  ┆ C      ┆ 2022-11-30 │
# └──────┴────────┴────────────┘
# 2024-04-13 20:40:31.132 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬────────┬──────┐
# │ SUN ┆ SUN_DC ┆ date │
# │ --- ┆ ---    ┆ ---  │
# │ u32 ┆ u32    ┆ u32  │
# ╞═════╪════════╪══════╡
# │ 0   ┆ 0      ┆ 0    │
# └─────┴────────┴──────┘
# 2024-04-13 20:40:31.139 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_261, 3)
# ┌─────┬───────┬────────────┐
# │ RF  ┆ RF_DC ┆ date       │
# │ --- ┆ ---   ┆ ---        │
# │ f32 ┆ str   ┆ date       │
# ╞═════╪═══════╪════════════╡
# │ 0.0 ┆ C     ┆ 1992-07-01 │
# │ 1.7 ┆ C     ┆ 1992-07-02 │
# │ 0.0 ┆ C     ┆ 1992-07-03 │
# │ 1.8 ┆ C     ┆ 1992-07-04 │
# │ 1.0 ┆ C     ┆ 1992-07-05 │
# │ …   ┆ …     ┆ …          │
# │ 0.0 ┆ C     ┆ 2023-04-26 │
# │ 0.0 ┆ C     ┆ 2023-04-27 │
# │ 1.2 ┆ C     ┆ 2023-04-28 │
# │ 0.0 ┆ C     ┆ 2023-04-29 │
# │ 0.0 ┆ C     ┆ 2023-04-30 │
# └─────┴───────┴────────────┘
# 2024-04-13 20:40:31.141 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬───────┬──────┐
# │ RF  ┆ RF_DC ┆ date │
# │ --- ┆ ---   ┆ ---  │
# │ u32 ┆ u32   ┆ u32  │
# ╞═════╪═══════╪══════╡
# │ 11  ┆ 11    ┆ 0    │
# └─────┴───────┴──────┘
# 2024-04-13 20:40:31.146 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (8_642, 3)
# ┌─────┬───────┬────────────┐
# │ UV  ┆ UV_DC ┆ date       │
# │ --- ┆ ---   ┆ ---        │
# │ f32 ┆ str   ┆ date       │
# ╞═════╪═══════╪════════════╡
# │ 7.0 ┆ C     ┆ 1999-08-01 │
# │ 3.0 ┆ C     ┆ 1999-08-02 │
# │ 3.0 ┆ C     ┆ 1999-08-03 │
# │ 3.0 ┆ C     ┆ 1999-08-04 │
# │ 4.0 ┆ C     ┆ 1999-08-05 │
# │ …   ┆ …     ┆ …          │
# │ 0.3 ┆ C     ┆ 2023-03-27 │
# │ 0.5 ┆ C     ┆ 2023-03-28 │
# │ 2.0 ┆ C     ┆ 2023-03-29 │
# │ 0.9 ┆ C     ┆ 2023-03-30 │
# │ 0.6 ┆ C     ┆ 2023-03-31 │
# └─────┴───────┴────────────┘
# 2024-04-13 20:40:31.147 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌─────┬───────┬──────┐
# │ UV  ┆ UV_DC ┆ date │
# │ --- ┆ ---   ┆ ---  │
# │ u32 ┆ u32   ┆ u32  │
# ╞═════╪═══════╪══════╡
# │ 11  ┆ 11    ┆ 0    │
# └─────┴───────┴──────┘
# 2024-04-13 20:40:31.154 | INFO     | utils.DataPreprocessing:load_csv:129 - shape: (11_261, 3)
# ┌──────┬─────────┬────────────┐
# │ WSPD ┆ WSPD_DC ┆ date       │
# │ ---  ┆ ---     ┆ ---        │
# │ f32  ┆ str     ┆ date       │
# ╞══════╪═════════╪════════════╡
# │ 6.4  ┆ #       ┆ 1992-07-01 │
# │ 7.4  ┆ #       ┆ 1992-07-02 │
# │ 8.5  ┆ C       ┆ 1992-07-03 │
# │ 11.0 ┆ C       ┆ 1992-07-04 │
# │ 14.5 ┆ C       ┆ 1992-07-05 │
# │ …    ┆ …       ┆ …          │
# │ 8.8  ┆ C       ┆ 2023-04-26 │
# │ 13.3 ┆ C       ┆ 2023-04-27 │
# │ 12.3 ┆ C       ┆ 2023-04-28 │
# │ 6.5  ┆ C       ┆ 2023-04-29 │
# │ 8.4  ┆ C       ┆ 2023-04-30 │
# └──────┴─────────┴────────────┘
# 2024-04-13 20:40:31.155 | INFO     | utils.DataPreprocessing:load_csv:131 - shape: (1, 3)
# ┌──────┬─────────┬──────┐
# │ WSPD ┆ WSPD_DC ┆ date │
# │ ---  ┆ ---     ┆ ---  │
# │ u32  ┆ u32     ┆ u32  │
# ╞══════╪═════════╪══════╡
# │ 21   ┆ 21      ┆ 0    │
# └──────┴─────────┴──────┘
# 2024-04-13 20:40:31.188 | INFO     | utils.DataPreprocessing:feature_engineering:262 - RF
# 2024-04-13 20:40:31.189 | DEBUG    | utils.DataPreprocessing:remove_outliers:168 - shape: (5, 3)
# ┌─────┬───────┬────────────┐
# │ RF  ┆ RF_DC ┆ date       │
# │ --- ┆ ---   ┆ ---        │
# │ f32 ┆ str   ┆ date       │
# ╞═════╪═══════╪════════════╡
# │ 0.0 ┆ C     ┆ 1992-07-01 │
# │ 1.7 ┆ C     ┆ 1992-07-02 │
# │ 0.0 ┆ C     ┆ 1992-07-03 │
# │ 1.8 ┆ C     ┆ 1992-07-04 │
# │ 1.0 ┆ C     ┆ 1992-07-05 │
# └─────┴───────┴────────────┘
# 2024-04-13 20:40:31.191 | INFO     | utils.DataPreprocessing:feature_engineering:265 - WSPD
# 2024-04-13 20:40:31.192 | DEBUG    | utils.DataPreprocessing:remove_outliers:168 - shape: (5, 3)
# ┌──────┬─────────┬────────────┐
# │ WSPD ┆ WSPD_DC ┆ date       │
# │ ---  ┆ ---     ┆ ---        │
# │ f32  ┆ str     ┆ date       │
# ╞══════╪═════════╪════════════╡
# │ 6.4  ┆ #       ┆ 1992-07-01 │
# │ 7.4  ┆ #       ┆ 1992-07-02 │
# │ 8.5  ┆ C       ┆ 1992-07-03 │
# │ 11.0 ┆ C       ┆ 1992-07-04 │
# │ 14.5 ┆ C       ┆ 1992-07-05 │
# └──────┴─────────┴────────────┘
# 2024-04-13 20:40:31.194 | SUCCESS  | utils.DataPreprocessing:feature_engineering:270 - Removed 76 outliers from RF
# 2024-04-13 20:40:31.194 | SUCCESS  | utils.DataPreprocessing:feature_engineering:271 - Removed 56 outliers from WSPD
# 2024-04-13 20:40:31.229 | INFO     | utils.DataPreprocessing:feature_engineering:284 - shape: (8_523, 16)
# ┌───────────┬────────────┬───────────┬──────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP  ┆ date       ┆ GSR       ┆ SUN  ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---       ┆ ---        ┆ ---       ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ f32       ┆ date       ┆ f32       ┆ f32  ┆   ┆ i8         ┆ i8         ┆ i16       ┆ i8      │
# ╞═══════════╪════════════╪═══════════╪══════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 29.200001 ┆ 1999-08-01 ┆ 25.1      ┆ 11.6 ┆ … ┆ 1          ┆ 30         ┆ 213       ┆ 3       │
# │ 29.1      ┆ 1999-08-02 ┆ 15.13     ┆ 7.0  ┆ … ┆ 2          ┆ 31         ┆ 214       ┆ 3       │
# │ 29.0      ┆ 1999-08-03 ┆ 11.85     ┆ 2.4  ┆ … ┆ 3          ┆ 31         ┆ 215       ┆ 3       │
# │ 27.5      ┆ 1999-08-04 ┆ 10.67     ┆ 2.3  ┆ … ┆ 4          ┆ 31         ┆ 216       ┆ 3       │
# │ 27.9      ┆ 1999-08-05 ┆ 15.18     ┆ 6.0  ┆ … ┆ 5          ┆ 31         ┆ 217       ┆ 3       │
# │ …         ┆ …          ┆ …         ┆ …    ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 22.200001 ┆ 2022-11-26 ┆ 4.27      ┆ 0.2  ┆ … ┆ 26         ┆ 47         ┆ 330       ┆ 4       │
# │ 22.4      ┆ 2022-11-27 ┆ 3.66      ┆ 0.0  ┆ … ┆ 27         ┆ 47         ┆ 331       ┆ 4       │
# │ 25.4      ┆ 2022-11-28 ┆ 11.34     ┆ 4.2  ┆ … ┆ 28         ┆ 48         ┆ 332       ┆ 4       │
# │ 25.1      ┆ 2022-11-29 ┆ 17.049999 ┆ 8.9  ┆ … ┆ 29         ┆ 48         ┆ 333       ┆ 4       │
# │ 22.1      ┆ 2022-11-30 ┆ 7.06      ┆ 2.6  ┆ … ┆ 30         ┆ 48         ┆ 334       ┆ 4       │
# └───────────┴────────────┴───────────┴──────┴───┴────────────┴────────────┴───────────┴─────────┘
# 2024-04-13 20:40:31.230 | INFO     | utils.DataPreprocessing:feature_engineering:285 - shape: (1, 16)
# ┌──────────┬──────┬─────┬─────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP ┆ date ┆ GSR ┆ SUN ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---      ┆ ---  ┆ --- ┆ --- ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ u32      ┆ u32  ┆ u32 ┆ u32 ┆   ┆ u32        ┆ u32        ┆ u32       ┆ u32     │
# ╞══════════╪══════╪═════╪═════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 0        ┆ 0    ┆ 0   ┆ 0   ┆ … ┆ 0          ┆ 0          ┆ 0         ┆ 0       │
# └──────────┴──────┴─────┴─────┴───┴────────────┴────────────┴───────────┴─────────┘
# 2024-04-13 20:40:31.232 | INFO     | utils.DataPreprocessing:feature_engineering:297 - shape: (8_523, 16)
# ┌───────────┬────────────┬───────────┬──────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP  ┆ date       ┆ GSR       ┆ SUN  ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---       ┆ ---        ┆ ---       ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ f32       ┆ date       ┆ f32       ┆ f32  ┆   ┆ f32        ┆ f32        ┆ f32       ┆ f32     │
# ╞═══════════╪════════════╪═══════════╪══════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 29.200001 ┆ 1999-08-01 ┆ 25.1      ┆ 11.6 ┆ … ┆ 1.0        ┆ 30.0       ┆ 213.0     ┆ 3.0     │
# │ 29.1      ┆ 1999-08-02 ┆ 15.13     ┆ 7.0  ┆ … ┆ 2.0        ┆ 31.0       ┆ 214.0     ┆ 3.0     │
# │ 29.0      ┆ 1999-08-03 ┆ 11.85     ┆ 2.4  ┆ … ┆ 3.0        ┆ 31.0       ┆ 215.0     ┆ 3.0     │
# │ 27.5      ┆ 1999-08-04 ┆ 10.67     ┆ 2.3  ┆ … ┆ 4.0        ┆ 31.0       ┆ 216.0     ┆ 3.0     │
# │ 27.9      ┆ 1999-08-05 ┆ 15.18     ┆ 6.0  ┆ … ┆ 5.0        ┆ 31.0       ┆ 217.0     ┆ 3.0     │
# │ …         ┆ …          ┆ …         ┆ …    ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 22.200001 ┆ 2022-11-26 ┆ 4.27      ┆ 0.2  ┆ … ┆ 26.0       ┆ 47.0       ┆ 330.0     ┆ 4.0     │
# │ 22.4      ┆ 2022-11-27 ┆ 3.66      ┆ 0.0  ┆ … ┆ 27.0       ┆ 47.0       ┆ 331.0     ┆ 4.0     │
# │ 25.4      ┆ 2022-11-28 ┆ 11.34     ┆ 4.2  ┆ … ┆ 28.0       ┆ 48.0       ┆ 332.0     ┆ 4.0     │
# │ 25.1      ┆ 2022-11-29 ┆ 17.049999 ┆ 8.9  ┆ … ┆ 29.0       ┆ 48.0       ┆ 333.0     ┆ 4.0     │
# │ 22.1      ┆ 2022-11-30 ┆ 7.06      ┆ 2.6  ┆ … ┆ 30.0       ┆ 48.0       ┆ 334.0     ┆ 4.0     │
# └───────────┴────────────┴───────────┴──────┴───┴────────────┴────────────┴───────────┴─────────┘
# /home/argonaut/programming/HK-Temperature-Forecasting

# %%
print(data.train)
print(data.test)
# Out:
# shape: (6_818, 16)
# ┌───────────┬────────────┬───────────┬──────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP  ┆ date       ┆ GSR       ┆ SUN  ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---       ┆ ---        ┆ ---       ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ f32       ┆ date       ┆ f32       ┆ f32  ┆   ┆ f32        ┆ f32        ┆ f32       ┆ f32     │
# ╞═══════════╪════════════╪═══════════╪══════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 29.200001 ┆ 1999-08-01 ┆ 25.1      ┆ 11.6 ┆ … ┆ 1.0        ┆ 30.0       ┆ 213.0     ┆ 3.0     │
# │ 29.1      ┆ 1999-08-02 ┆ 15.13     ┆ 7.0  ┆ … ┆ 2.0        ┆ 31.0       ┆ 214.0     ┆ 3.0     │
# │ 29.0      ┆ 1999-08-03 ┆ 11.85     ┆ 2.4  ┆ … ┆ 3.0        ┆ 31.0       ┆ 215.0     ┆ 3.0     │
# │ 27.5      ┆ 1999-08-04 ┆ 10.67     ┆ 2.3  ┆ … ┆ 4.0        ┆ 31.0       ┆ 216.0     ┆ 3.0     │
# │ 27.9      ┆ 1999-08-05 ┆ 15.18     ┆ 6.0  ┆ … ┆ 5.0        ┆ 31.0       ┆ 217.0     ┆ 3.0     │
# │ …         ┆ …          ┆ …         ┆ …    ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 22.4      ┆ 2018-03-27 ┆ 18.01     ┆ 8.2  ┆ … ┆ 27.0       ┆ 13.0       ┆ 86.0      ┆ 1.0     │
# │ 22.0      ┆ 2018-03-28 ┆ 21.469999 ┆ 8.7  ┆ … ┆ 28.0       ┆ 13.0       ┆ 87.0      ┆ 1.0     │
# │ 22.200001 ┆ 2018-03-29 ┆ 19.84     ┆ 7.1  ┆ … ┆ 29.0       ┆ 13.0       ┆ 88.0      ┆ 1.0     │
# │ 22.799999 ┆ 2018-03-30 ┆ 22.84     ┆ 9.9  ┆ … ┆ 30.0       ┆ 13.0       ┆ 89.0      ┆ 1.0     │
# │ 22.799999 ┆ 2018-03-31 ┆ 24.91     ┆ 10.6 ┆ … ┆ 31.0       ┆ 13.0       ┆ 90.0      ┆ 1.0     │
# └───────────┴────────────┴───────────┴──────┴───┴────────────┴────────────┴───────────┴─────────┘
# shape: (1_705, 16)
# ┌───────────┬────────────┬───────────┬──────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP  ┆ date       ┆ GSR       ┆ SUN  ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---       ┆ ---        ┆ ---       ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ f32       ┆ date       ┆ f32       ┆ f32  ┆   ┆ f32        ┆ f32        ┆ f32       ┆ f32     │
# ╞═══════════╪════════════╪═══════════╪══════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 22.9      ┆ 2018-04-01 ┆ 22.33     ┆ 9.7  ┆ … ┆ 1.0        ┆ 13.0       ┆ 91.0      ┆ 2.0     │
# │ 23.5      ┆ 2018-04-02 ┆ 21.41     ┆ 10.4 ┆ … ┆ 2.0        ┆ 14.0       ┆ 92.0      ┆ 2.0     │
# │ 24.0      ┆ 2018-04-03 ┆ 24.17     ┆ 10.8 ┆ … ┆ 3.0        ┆ 14.0       ┆ 93.0      ┆ 2.0     │
# │ 24.200001 ┆ 2018-04-04 ┆ 23.389999 ┆ 10.5 ┆ … ┆ 4.0        ┆ 14.0       ┆ 94.0      ┆ 2.0     │
# │ 24.0      ┆ 2018-04-05 ┆ 19.129999 ┆ 8.8  ┆ … ┆ 5.0        ┆ 14.0       ┆ 95.0      ┆ 2.0     │
# │ …         ┆ …          ┆ …         ┆ …    ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 22.200001 ┆ 2022-11-26 ┆ 4.27      ┆ 0.2  ┆ … ┆ 26.0       ┆ 47.0       ┆ 330.0     ┆ 4.0     │
# │ 22.4      ┆ 2022-11-27 ┆ 3.66      ┆ 0.0  ┆ … ┆ 27.0       ┆ 47.0       ┆ 331.0     ┆ 4.0     │
# │ 25.4      ┆ 2022-11-28 ┆ 11.34     ┆ 4.2  ┆ … ┆ 28.0       ┆ 48.0       ┆ 332.0     ┆ 4.0     │
# │ 25.1      ┆ 2022-11-29 ┆ 17.049999 ┆ 8.9  ┆ … ┆ 29.0       ┆ 48.0       ┆ 333.0     ┆ 4.0     │
# │ 22.1      ┆ 2022-11-30 ┆ 7.06      ┆ 2.6  ┆ … ┆ 30.0       ┆ 48.0       ┆ 334.0     ┆ 4.0     │
# └───────────┴────────────┴───────────┴──────┴───┴────────────┴────────────┴───────────┴─────────┘

# %%
import polars as pl
X_train, y_train = pl.DataFrame(data.train).drop(["date"]), pl.DataFrame(data.train)["AVG_TEMP"].shift(-1)
# remove the last row
X_train = X_train.slice(0, X_train.shape[0] - 1)
y_train = y_train.slice(0, y_train.shape[0] - 1).to_numpy()
print(X_train, y_train)

X_test, y_test = pl.DataFrame(data.test).drop(["date"]), pl.DataFrame(data.test)["AVG_TEMP"].shift(-1)
# remove the last row
X_test = X_test.slice(0, X_test.shape[0] - 1)
y_test = y_test.slice(0, y_test.shape[0] - 1).to_numpy()
# Out:
# shape: (6_817, 15)
# ┌───────────┬───────────┬──────┬──────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ AVG_TEMP  ┆ GSR       ┆ SUN  ┆ RH   ┆ … ┆ dayofmonth ┆ weekofyear ┆ dayofyear ┆ quarter │
# │ ---       ┆ ---       ┆ ---  ┆ ---  ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ f32       ┆ f32       ┆ f32  ┆ f32  ┆   ┆ f32        ┆ f32        ┆ f32       ┆ f32     │
# ╞═══════════╪═══════════╪══════╪══════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 29.200001 ┆ 25.1      ┆ 11.6 ┆ 79.0 ┆ … ┆ 1.0        ┆ 30.0       ┆ 213.0     ┆ 3.0     │
# │ 29.1      ┆ 15.13     ┆ 7.0  ┆ 82.0 ┆ … ┆ 2.0        ┆ 31.0       ┆ 214.0     ┆ 3.0     │
# │ 29.0      ┆ 11.85     ┆ 2.4  ┆ 83.0 ┆ … ┆ 3.0        ┆ 31.0       ┆ 215.0     ┆ 3.0     │
# │ 27.5      ┆ 10.67     ┆ 2.3  ┆ 87.0 ┆ … ┆ 4.0        ┆ 31.0       ┆ 216.0     ┆ 3.0     │
# │ 27.9      ┆ 15.18     ┆ 6.0  ┆ 82.0 ┆ … ┆ 5.0        ┆ 31.0       ┆ 217.0     ┆ 3.0     │
# │ …         ┆ …         ┆ …    ┆ …    ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 22.1      ┆ 15.75     ┆ 6.8  ┆ 70.0 ┆ … ┆ 26.0       ┆ 13.0       ┆ 85.0      ┆ 1.0     │
# │ 22.4      ┆ 18.01     ┆ 8.2  ┆ 72.0 ┆ … ┆ 27.0       ┆ 13.0       ┆ 86.0      ┆ 1.0     │
# │ 22.0      ┆ 21.469999 ┆ 8.7  ┆ 78.0 ┆ … ┆ 28.0       ┆ 13.0       ┆ 87.0      ┆ 1.0     │
# │ 22.200001 ┆ 19.84     ┆ 7.1  ┆ 78.0 ┆ … ┆ 29.0       ┆ 13.0       ┆ 88.0      ┆ 1.0     │
# │ 22.799999 ┆ 22.84     ┆ 9.9  ┆ 75.0 ┆ … ┆ 30.0       ┆ 13.0       ┆ 89.0      ┆ 1.0     │
# └───────────┴───────────┴──────┴──────┴───┴────────────┴────────────┴───────────┴─────────┘ [29.1 29.  27.5 ... 22.2 22.8 22.8]

# %%
# turn polar dataframe to pandas dataframe
# X_train = X_train.to_pandas()
# y_train = y_train.to_pandas()
# X_test = X_test.to_pandas()
# y_test = y_test.to_pandas()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
mm = MinMaxScaler()
ss = StandardScaler()

X_train_trans, X_test_trans = ss.fit_transform(X_train), ss.fit_transform(X_test)
y_train_trans, y_test_trans = mm.fit_transform(y_train.reshape(-1, 1)), mm.fit_transform(y_test.reshape(-1, 1))

# %%
import numpy as np

# split a multivariate sequence past, future samples (X and y)
def split_sequences(input_sequences, output_sequence, n_steps_in, n_steps_out):
    X, y = list(), list() # instantiate X and y
    for i in range(len(input_sequences)):
        # find the end of the input, output sequence
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out - 1
        # check if we are beyond the dataset
        if out_end_ix > len(input_sequences): break
        # gather input and output of the pattern
        seq_x, seq_y = input_sequences[i:end_ix], output_sequence[end_ix-1:out_end_ix, -1]
        X.append(seq_x), y.append(seq_y)
    return np.array(X), np.array(y)

X_train_ss, y_train_mm = split_sequences(X_train_trans, y_train_trans, lag, n_steps_out)
X_test_ss, y_test_mm = split_sequences(X_test_trans, y_test_trans, lag, n_steps_out)
print(X_train_ss.shape, y_train_mm.shape)
# Out:
# (6798, 20, 15) (6798, 1)

# %%
assert y_train_mm[0].all() == y_train_trans[lag-1:lag+n_steps_out-1].squeeze(1).all()

# %%
import torch
from torch.autograd import Variable

# convert to pytorch tensors
X_train_tensors = Variable(torch.Tensor(X_train_ss))
X_test_tensors = Variable(torch.Tensor(X_test_ss))

y_train_tensors = Variable(torch.Tensor(y_train_mm))
y_test_tensors = Variable(torch.Tensor(y_test_mm))

# %%
# move to GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
X_train_tensors, X_test_tensors = X_train_tensors.to(device), X_test_tensors.to(device)
y_train_tensors, y_test_tensors = y_train_tensors.to(device), y_test_tensors.to(device)

# %%
print(X_train_tensors.shape, y_train_tensors.shape)
# Out:
# torch.Size([6798, 20, 15]) torch.Size([6798, 1])

# %%
# reshaping to rows, timestamps, features
X_train_tensors_final = torch.reshape(X_train_tensors,   
                                      (X_train_tensors.shape[0], lag, 
                                       X_train_tensors.shape[2]))
X_test_tensors_final = torch.reshape(X_test_tensors,  
                                     (X_test_tensors.shape[0], lag, 
                                      X_test_tensors.shape[2])) 

print("Training Shape:", X_train_tensors_final.shape, y_train_tensors.shape)
print("Testing Shape:", X_test_tensors_final.shape, y_test_tensors.shape)
# Out:
# Training Shape: torch.Size([6798, 20, 15]) torch.Size([6798, 1])
# Testing Shape: torch.Size([1685, 20, 15]) torch.Size([1685, 1])

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class LSTM(nn.Module):
    
    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super().__init__()
        self.num_classes = num_classes # output size
        self.num_layers = num_layers # number of recurrent layers in the lstm
        self.input_size = input_size # input size
        self.hidden_size = hidden_size # neurons in each lstm layer
        # LSTM model
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                            num_layers=num_layers, batch_first=True, dropout=0.5) # lstm
        self.fc_1 =  nn.Linear(hidden_size, 128) # fully connected 
        self.fc_2 = nn.Linear(128, num_classes) # fully connected last layer
        self.relu = nn.ReLU()
        
    def forward(self,x):
        # hidden state
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        # cell state
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size))
        # propagate input through LSTM
        output, (hn, cn) = self.lstm(x, (h_0, c_0)) # (input, hidden, and internal state)
        hn = hn.view(-1, self.hidden_size) # reshaping the data for Dense layer next
        out = self.relu(hn)
        out = self.fc_1(out) # first dense
        out = self.relu(out) # relu
        out = self.fc_2(out) # final output
        return out

# %%
# Get cpu or gpu device for training.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
from model import PatchTST

patch_len = 20
stride = 20

model = PatchTST(
    c_in=n_features,
    context_window=lag,
    target_window=n_steps_out,
    patch_len=patch_len,
    stride=stride,
)

model = model.to(device)
print(model)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
# optimizer = torch.optim.SGD(model.parameters(), lr=0.02, momentum=0.9, weight_decay=5e-4)
loss_fn = torch.nn.MSELoss()
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.5, patience=3, verbose=True)

training_loss = []
testing_loss = []
# Out:
# PatchTST(
#   (revin_layer): RevIN()
#   (padding_patch_layer): ReplicationPad1d((0, 20))
#   (backbone): TSTiEncoder(
#     (W_P): Linear(in_features=20, out_features=16, bias=True)
#     (dropout): Dropout(p=0.3, inplace=False)
#     (encoder): TSTEncoder(
#       (layers): ModuleList(
#         (0-2): 3 x TSTEncoderLayer(
#           (self_attn): _MultiheadAttention(
#             (W_Q): Linear(in_features=16, out_features=16, bias=True)
#             (W_K): Linear(in_features=16, out_features=16, bias=True)
#             (W_V): Linear(in_features=16, out_features=16, bias=True)
#             (sdp_attn): _ScaledDotProductAttention(
#               (attn_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (to_out): Sequential(
#               (0): Linear(in_features=16, out_features=16, bias=True)
#               (1): Dropout(p=0.3, inplace=False)
#             )
#           )
#           (dropout_attn): Dropout(p=0.3, inplace=False)
#           (norm_attn): Sequential(
#             (0): Transpose()
#             (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): Transpose()
#           )
#           (ff): Sequential(
#             (0): Linear(in_features=16, out_features=128, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.3, inplace=False)
#             (3): Linear(in_features=128, out_features=16, bias=True)
#           )
#           (dropout_ffn): Dropout(p=0.3, inplace=False)
#           (norm_ffn): Sequential(
#             (0): Transpose()
#             (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): Transpose()
#           )
#         )
#       )
#     )
#   )
#   (head): Flatten_Head_For_Single_Output(
#     (flatten): Flatten(start_dim=-3, end_dim=-1)
#     (linear): Linear(in_features=480, out_features=1, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
# )
# /home/argonaut/programming/HK-Temperature-Forecasting/venv/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
def training_loop(n_epochs, model, optimiser, loss_fn, scheduler, X_train, y_train,
                  X_test, y_test):
    for epoch in range(n_epochs):
        model.train()
        outputs = model.forward(X_train) # forward pass
        optimiser.zero_grad() # calculate the gradient, manually setting to 0
        # obtain the loss function
        loss = loss_fn(outputs, y_train)
        loss.backward() # calculates the loss of the loss function
        optimiser.step() # improve from loss, i.e backprop
        # test loss
        model.eval()
        test_preds = model(X_test)
        test_loss = loss_fn(test_preds, y_test)
        scheduler.step(test_loss)
        lr = optimiser.param_groups[0]['lr']
        # if epoch % 100 == 0:
        print(f"Epoch: {epoch}, train loss: {loss.item():.5f}, test loss: {test_loss.item():.5f}, learning rate: {lr:.5f}")
        training_loss.append(loss.item())
        testing_loss.append(test_loss.item())

training_loop(n_epochs=n_epochs,
              model=model,
              optimiser=optimizer,
              loss_fn=loss_fn,
              scheduler=scheduler,
              X_train=X_train_tensors_final,
              y_train=y_train_tensors,
              X_test=X_test_tensors_final,
              y_test=y_test_tensors)
# Out:
# Epoch: 0, train loss: 1.33656, test loss: 1.41105, learning rate: 0.01000
# Epoch: 1, train loss: 1.26504, test loss: 1.32412, learning rate: 0.01000
# Epoch: 2, train loss: 1.23632, test loss: 1.33962, learning rate: 0.01000
# Epoch: 3, train loss: 1.20351, test loss: 1.57392, learning rate: 0.01000
# Epoch: 4, train loss: 1.20636, test loss: 1.63673, learning rate: 0.01000
# Epoch: 5, train loss: 1.20084, test loss: 1.51879, learning rate: 0.00500
# Epoch: 6, train loss: 1.19477, test loss: 1.41720, learning rate: 0.00500
# Epoch: 7, train loss: 1.19475, test loss: 1.35628, learning rate: 0.00500
# Epoch: 8, train loss: 1.19007, test loss: 1.32620, learning rate: 0.00500
# Epoch: 9, train loss: 1.18858, test loss: 1.31316, learning rate: 0.00500
# Epoch: 10, train loss: 1.18681, test loss: 1.30148, learning rate: 0.00500
# Epoch: 11, train loss: 1.18742, test loss: 1.28839, learning rate: 0.00500
# Epoch: 12, train loss: 1.18516, test loss: 1.27766, learning rate: 0.00500
# Epoch: 13, train loss: 1.18335, test loss: 1.27040, learning rate: 0.00500
# Epoch: 14, train loss: 1.17856, test loss: 1.26525, learning rate: 0.00500
# Epoch: 15, train loss: 1.18149, test loss: 1.25962, learning rate: 0.00500
# Epoch: 16, train loss: 1.18119, test loss: 1.25438, learning rate: 0.00500
# Epoch: 17, train loss: 1.17822, test loss: 1.25134, learning rate: 0.00500
# Epoch: 18, train loss: 1.17609, test loss: 1.25003, learning rate: 0.00500
# Epoch: 19, train loss: 1.17534, test loss: 1.24938, learning rate: 0.00500
# Epoch: 20, train loss: 1.17510, test loss: 1.24901, learning rate: 0.00500
# Epoch: 21, train loss: 1.17415, test loss: 1.24902, learning rate: 0.00500
# Epoch: 22, train loss: 1.17180, test loss: 1.24913, learning rate: 0.00500
# Epoch: 23, train loss: 1.17212, test loss: 1.24893, learning rate: 0.00500
# Epoch: 24, train loss: 1.17163, test loss: 1.24831, learning rate: 0.00500
# Epoch: 25, train loss: 1.17140, test loss: 1.24773, learning rate: 0.00500
# Epoch: 26, train loss: 1.17325, test loss: 1.24771, learning rate: 0.00500
# Epoch: 27, train loss: 1.17280, test loss: 1.24856, learning rate: 0.00500
# Epoch: 28, train loss: 1.16904, test loss: 1.25012, learning rate: 0.00500
# Epoch: 29, train loss: 1.16792, test loss: 1.25219, learning rate: 0.00250
# Epoch: 30, train loss: 1.16984, test loss: 1.25231, learning rate: 0.00250
# Epoch: 31, train loss: 1.16798, test loss: 1.25203, learning rate: 0.00250
# Epoch: 32, train loss: 1.16790, test loss: 1.25120, learning rate: 0.00250
# Epoch: 33, train loss: 1.16798, test loss: 1.25021, learning rate: 0.00125
# Epoch: 34, train loss: 1.16787, test loss: 1.24919, learning rate: 0.00125
# Epoch: 35, train loss: 1.16670, test loss: 1.24824, learning rate: 0.00125
# Epoch: 36, train loss: 1.16853, test loss: 1.24744, learning rate: 0.00125
# Epoch: 37, train loss: 1.16730, test loss: 1.24678, learning rate: 0.00125
# Epoch: 38, train loss: 1.16682, test loss: 1.24628, learning rate: 0.00125
# Epoch: 39, train loss: 1.16790, test loss: 1.24593, learning rate: 0.00125
# Epoch: 40, train loss: 1.16625, test loss: 1.24571, learning rate: 0.00125
# Epoch: 41, train loss: 1.16724, test loss: 1.24560, learning rate: 0.00125
# Epoch: 42, train loss: 1.16601, test loss: 1.24551, learning rate: 0.00125
# Epoch: 43, train loss: 1.16612, test loss: 1.24540, learning rate: 0.00125
# Epoch: 44, train loss: 1.16500, test loss: 1.24533, learning rate: 0.00125
# Epoch: 45, train loss: 1.16607, test loss: 1.24523, learning rate: 0.00125
# Epoch: 46, train loss: 1.16651, test loss: 1.24506, learning rate: 0.00125
# Epoch: 47, train loss: 1.16507, test loss: 1.24492, learning rate: 0.00125
# Epoch: 48, train loss: 1.16714, test loss: 1.24481, learning rate: 0.00125
# Epoch: 49, train loss: 1.16682, test loss: 1.24475, learning rate: 0.00125
# Epoch: 50, train loss: 1.16504, test loss: 1.24463, learning rate: 0.00125
# Epoch: 51, train loss: 1.16572, test loss: 1.24445, learning rate: 0.00125
# Epoch: 52, train loss: 1.16561, test loss: 1.24424, learning rate: 0.00125
# Epoch: 53, train loss: 1.16561, test loss: 1.24409, learning rate: 0.00125
# Epoch: 54, train loss: 1.16428, test loss: 1.24392, learning rate: 0.00125
# Epoch: 55, train loss: 1.16559, test loss: 1.24374, learning rate: 0.00125
# Epoch: 56, train loss: 1.16678, test loss: 1.24355, learning rate: 0.00125
# Epoch: 57, train loss: 1.16523, test loss: 1.24334, learning rate: 0.00125
# Epoch: 58, train loss: 1.16493, test loss: 1.24315, learning rate: 0.00125
# Epoch: 59, train loss: 1.16466, test loss: 1.24296, learning rate: 0.00125

# %%
# plot the loss function
import matplotlib.pyplot as plt
plt.plot(training_loss, label="Training Loss")
plt.plot(testing_loss, label="Testing Loss")
plt.legend()
plt.savefig("loss.png")

# %%
# make predictions
test_predict = model(X_test_tensors_final)
data_predict = test_predict.cpu().detach().numpy() # numpy conversion
data_predict = mm.inverse_transform(data_predict) # reverse transformation
dataY_plot = mm.inverse_transform(y_test_mm) # reverse transformation

print(test_predict.shape)
# Out:
# torch.Size([1685, 1])

# %%
print(y_test_tensors.shape)
# Out:
# torch.Size([1685, 1])

# %%
print(data_predict[:, 0])
# Out:
# [-4.2154737 -4.2042513 -4.1977153 ... 39.167557  39.25627   39.233315 ]

# %%
print(dataY_plot.shape, data_predict.shape)
# Out:
# (1685, 1) (1685, 1)

# %%
print(len(dataY_plot[0, :]))
print(len(data_predict[0, :]))
# Out:
# 1
# 1

# %%
# get the r2 score, mean squared error
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2 = r2_score(dataY_plot[:, -1], data_predict[:, -1])
mse = mean_squared_error(dataY_plot[:, -1], data_predict[:, -1])
mae = mean_absolute_error(dataY_plot[:, -1], data_predict[:, -1])

print("R2 Score: %1.5f" % r2)
print("Mean Squared Error: %1.5f" % mse)
print("Mean Absolute Error: %1.5f" % mae)
# Out:
# R2 Score: -29.99493
# Mean Squared Error: 686.42554
# Mean Absolute Error: 22.57998

# %%
# get the r2 score, mean squared error
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2 = r2_score(dataY_plot, data_predict)
mse = mean_squared_error(dataY_plot, data_predict)
mae = mean_absolute_error(dataY_plot, data_predict)

print("R2 Score: %1.5f" % r2)
print("Mean Squared Error: %1.5f" % mse)
print("Mean Absolute Error: %1.5f" % mae)
# Out:
# R2 Score: -29.99493
# Mean Squared Error: 686.42554
# Mean Absolute Error: 22.57998

# %%
import seaborn as sns
import matplotlib.pyplot as plt

x_values = np.arange(test_predict.shape[0])
# x_values = np.arange(n_steps_out)
fig, ax = plt.subplots(
    figsize=(15, 5),
)

plt.title("PatchTST autoregresser")
plt.title(f"n_past = {lag:}, n_future = {n_steps_out}", loc="right", fontsize=13)
plt.title(f"r2_score = {r2:1.4f}, mse = {mse:1.4f}, mae = {mae:1.4f}", loc="left", fontsize=11)

sns.scatterplot(x=x_values, y=dataY_plot[:, -1], ax=ax, label="True")
sns.scatterplot(x=x_values, y=data_predict[:, -1], ax=ax, label="Predicted")

# sns.scatterplot(x=x_values, y=dataY_plot[-1, :], ax=ax, label="True")
# sns.scatterplot(x=x_values, y=data_predict[-1, :], ax=ax, label="Predicted")

# plt.plot(dataY_plot[-1, :], label="True")
# plt.plot(data_predict[-1, :], label="Predicted")

plt.savefig("patchtst.png")
